# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
FILE_PATH = 'gdrive/My Drive/NN Capstone/Generated_Foraminifera/species_1/specimen_00/specimen_00.obj'

# %%
# %cd 'gdrive/My Drive/NN Capstone'
# !chmod +x binvox
# !./binvox
# Out:
# [Errno 2] No such file or directory: 'gdrive/My Drive/NN Capstone'
# /content/gdrive/My Drive/NN Capstone
#
# --- [binvox] mesh voxelizer, version 1.26, build #644 on 2017/10/22 15:19:22
# --- written by Patrick Min, 2004-2017
#
# Error: missing model filename
#
# Usage: binvox [-d <voxel dimension>] [-t <voxel file type>] [-c] [-v] <model filespec>
#   -license: show software license
#   -d: specify voxel grid size (default 256, max 1024)(no max when using -e)
#   -t: specify voxel file type (default binvox, also supported: hips, mira, vtk, raw, schematic, msh)
#   -c: z-buffer based carving method only
#   -dc: dilated carving, stop carving 1 voxel before intersection
#   -v: z-buffer based parity voting method only (default is both -c and -v)
#   -e: exact voxelization (any voxel with part of a triangle gets set)(does not use graphics card)
# Additional parameters:
#   -bb <minx> <miny> <minz> <maxx> <maxy> <maxz>: force a different input model bounding box
# ...

# %%
# !pwd
# !./binvox 'Generated_Foraminifera/species_1/specimen_00/specimen_00.obj'
# Out:
# /content/gdrive/My Drive/NN Capstone
#
# --- [binvox] mesh voxelizer, version 1.26, build #644 on 2017/10/22 15:19:22
# --- written by Patrick Min, 2004-2017
#
# loading model file...
# MeshFileIdentifier::*create_mesh_file(Generated_Foraminifera/species_1/specimen_00/specimen_00.obj)
# ObjMeshFile::load(Generated_Foraminifera/species_1/specimen_00/specimen_00.obj)
# 6271 Generated_Foraminifera/species_1/specimen_00/specimen_00.obj
#   material library:  specimen_00.mtl
#   ignoring object name [ Sphere.003_Sphere.004]
#   900 lines read  ignoring [usemtl None]
#   ignoring smooth shading directive [s 1]
#   1400 lines read  ignoring object name [ Sphere.002_Sphere.003]
#   2400 lines read  ignoring [usemtl None]
#   ignoring smooth shading directive [s 1]
#   2900 lines read  ignoring object name [ Sphere.001_Sphere.002]
#   3900 lines read  ignoring [usemtl None]
#   ignoring smooth shading directive [s 1]
#   4400 lines read  ignoring object name [ Sphere]
# ...

# %%
# !sudo apt-get install Xvfb
# !Xvfb :99 -screen 0 640x480x24 &
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package Xvfb
# /bin/bash: Xvfb: command not found

# %%
import numpy as np
path = 'Train_Input/species_1/specimen_08/'
normal = np.load(path+ 'View_08_n.npy')

# %%
import matplotlib.pyplot as plt
plt.imshow(normal,cmap='gray',interpolation='nearest')

# %%
shr = []
vish = np.random.randint(low=0, high=49, size=10)
for i in vish:
  shr.append(str(i).zfill(2))

shr
# Out:
# ['05', '44', '31', '32', '47', '45', '47', '31', '39', '31']

# %%
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
import shutil


for view in glob.iglob('Train_Input/species_2/specimen_*/.DS*'):
    print(view)
    #with open(view, 'rb') as f:
    #    model = binvox_rw.read_as_3d_array(f)
    head , tail = os.path.split(view)
    tail = os.path.splitext(tail)
    print (tail[0])
    #print(model.data)
    #voxel = np.array(model.data).astype(int)
    #np.save(head+'/'+tail[0], voxel)
    #os.remove(head +'/' + tail[0] + '.obj')
    #shutil.rmtree(head +'/Views')

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/NN Capstone
